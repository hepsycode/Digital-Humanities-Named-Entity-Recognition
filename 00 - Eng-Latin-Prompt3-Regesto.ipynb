# %%
import os
import json
import csv
import time
import faiss
import numpy as np
from sentence_transformers import SentenceTransformer
from bs4 import BeautifulSoup
import requests
from langchain.prompts.chat import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_mistralai import ChatMistralAI
from langchain.llms import Ollama
from langchain_anthropic import ChatAnthropic
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.callbacks.base import BaseCallbackHandler
from langchain.tools.base import Tool  
from typing import Callable

# %%
############### CONFIG ###################

# Load configuration from JSON (mistral, openai, ollama, anthropic, google)
CONFIG_FILE = "config/llm_config_openai.json"
MODELS_FILE = "config/llm_models.json"

# %%
########### FUNCTIONS ##########
def load_config(config_file):
    try:
        with open(config_file, 'r') as file:
            return json.load(file)
    except FileNotFoundError:
        print(f"Configuration file {config_file} not found.")
        return {}
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}")
        return {}

def extract_text_from_pdf(pdf_path):
    """
    Estrae e restituisce il testo dal file PDF specificato.
    """
    text = ""
    try:
        with open(pdf_path, 'rb') as f:
            reader = PyPDF2.PdfReader(f)
            for page in reader.pages:
                page_text = page.extract_text()
                if page_text:
                    text += page_text
    except Exception as e:
        print(f"Errore nell'estrazione del testo da {pdf_path}: {e}")
    return text

def save_to_file(file_path, content):
    with open(file_path, 'w') as file:
        file.write(content)

def save_metadata(file_path, metadata):
    with open(file_path, 'w') as file:
        json.dump(metadata, file, indent=4)

# %%
# Load configurations
config = load_config(CONFIG_FILE)
models_config = load_config(MODELS_FILE)

# %%
# Extract parameters from configuration
LLM = config.get("llm")
if not LLM:
    raise ValueError("LLM name must be specified in the configuration file.")

PRICE_PER_INPUT_TOKEN = config.get("price_per_input_token")
PRICE_PER_OUTPUT_TOKEN = config.get("price_per_output_token")
temperature = config.get("temperature")
max_retries = config.get("max_retries")
api_key = config.get("api_keys", {}).get(LLM.lower(), None)
base_url = config.get("base_url")

# Get model configuration
LLM_TYPE = 'Other'
llm_config = models_config.get(LLM, None)
if llm_config and LLM_TYPE != 'Ollama':
    # Update parameters dynamically
    llm_params = llm_config.get("params", {})
    llm_params["temperature"] = temperature
    llm_params["max_retries"] = max_retries
    llm_params["api_key"] = api_key
    llm_params["base_url"] = base_url

    # Initialize LLM
    llm_class = eval(llm_config["class"])
    llm_LangChain = llm_class(**llm_params)
    model_name = LLM  # Use LLM directly as the model name
elif LLM_TYPE == 'Ollama':
    llm_params = llm_config.get("params", {})
    llm_params["temperature"] = temperature
    llm_params["base_url"] = base_url

    # Initialize LLM
    llm_class = eval(llm_config["class"])
    llm_LangChain = llm_class(**llm_params)
    model_name = LLM  # Use LLM directly as the model name
else:
    raise ValueError(f"Model configuration for '{LLM}' not found in {MODELS_FILE}.")

# %%
import os
import PyPDF2

# Few-shot context
context = (
    "I due testi che sto per farti analizzare sono uguali. Uno in lingua inglese e uno in lingua latina."
)

task = (
    f"""Esegui named entity recognition ed estrapola anche i luoghi intesi come borghi, navi, carceri, mercati e luoghi similari.
    Estrapola anche oggetti.
    Inoltre, crea un breve regesto del documento di massimo 40 parole e individua la data del documento. 
    Trascrivi la data separatamente dal regesto nel seguente formato: anno, mese (a lettere) e giorno, senza interpunzioni tra anno, mese e giorno.
    Non includere le etichette "Regesto" e "Data del documento", in quanto irrilevanti."""
)

base_output_dir = f"Prompt3-Results-{model_name.lower()}-{temperature}"
base_output_json_dir = f"Prompt3-Results-{model_name.lower()}-{temperature}/JSON"

# Ensure output directory exists
os.makedirs(base_output_dir, exist_ok=True)
os.makedirs(base_output_json_dir, exist_ok=True)
    
# Specifica la cartella in cui cercare i file PDF
folder_path = "doc"  # <-- Sostituisci con il percorso corretto

# Dizionario per salvare le coppie di file: la chiave è il nome base, 
# e il valore è un dizionario con le chiavi 'english' e 'latin'
pairs = {}

# Scorri tutti i file nella cartella
for file in os.listdir(folder_path):
    if file.lower().endswith(".pdf"):
        # Se il file termina con "latino.pdf" è la versione in latino
        if file.lower().endswith("latino.pdf"):
            # Rimuovo gli ultimi 10 caratteri ("latino.pdf") per ottenere il nome base
            base_name = file[:-10]
            if base_name not in pairs:
                pairs[base_name] = {}
            pairs[base_name]['latin'] = os.path.join(folder_path, file)
        else:
            # Altrimenti, supponiamo sia la versione in inglese: rimuovo ".pdf"
            base_name = file[:-4]
            if base_name not in pairs:
                pairs[base_name] = {}
            pairs[base_name]['english'] = os.path.join(folder_path, file)

for base, files in pairs.items():
    # Verifica che esista la coppia (versione in inglese e versione in latino)
    if 'english' in files and 'latin' in files:
        english_text = extract_text_from_pdf(files['english'])
        latin_text   = extract_text_from_pdf(files['latin'])

        print(files['english'])

        ############ Save file ##########
        output_res_path = os.path.join(base_output_dir, os.path.basename(files['english']) + '.txt')
        print(output_res_path)
        metadata_path = os.path.join(base_output_json_dir, os.path.basename(files['english']) + '.json')
        print(metadata_path)

        ####################### Synthetic Modeling Operation ###########################
        # Chat few-shot prompt template
        chat_prompt = ChatPromptTemplate.from_messages(
            [
                ("system", "Sei un assistente esperto in Named Entity Recognition e analisi testuale, con una profonda conoscenza delle lingue moderna e latina."),
                (
                    "user",
                    f"Context:\n{context}\n\n"
                    "Testo in inglese: {english_text}"
                    "Testo in latino: {latin_text}"
                    f"Task:\n{task}\n\n"
                )
            ]
        )

        print(chat_prompt)

        # Start timer
        start_time = time.time()
        
        # Invoke the model
        response = chat_prompt | llm_LangChain
        result = response.invoke(
            {
                "english_text": english_text,
                "latin_text": latin_text
            }
        )

        # Stop timer
        end_time = time.time()
        execution_time = end_time - start_time  # Prompt Execution Time (in second)

        if LLM_TYPE != 'Ollama':
            output_res = result.content.strip()
        else:
            output_res = result.strip()
        print(result)
        
        if LLM_TYPE != 'Ollama':
            metadata = {
                "response_length": len(output_res),
                "execution_time": execution_time,
                "temperature": temperature,
                "usage": result.usage_metadata,
                "price_usd": result.usage_metadata.get("input_tokens", 0) * PRICE_PER_INPUT_TOKEN + result.usage_metadata.get("output_tokens", 0) * PRICE_PER_OUTPUT_TOKEN,
                "model_name": model_name
            }
        else:
            metadata = {
                "response_length": len(output_res),
                "execution_time": execution_time,
                "temperature": temperature,
                "model_name": model_name
            }

        save_to_file(output_res_path, output_res)
        save_metadata(metadata_path, metadata)

        print(f"Processed: {files['english']}")
        print(f"Results saved to: {base_output_dir}")
        print(f"Metadata saved to: {base_output_json_dir}")

    else:
        print(f"Attenzione: La coppia per '{base}' non è completa. File trovati: {list(files.keys())}")
# Out:
# doc\doc11.pdf
# Prompt3-Results-mistral-large-latest-1.0\doc11.pdf.txt
# Prompt3-Results-mistral-large-latest-1.0/JSON\doc11.pdf.json
# input_variables=['english_text', 'latin_text'] input_types={} partial_variables={} messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Sei un assistente esperto in Named Entity Recognition e analisi testuale, con una profonda conoscenza delle lingue moderna e latina.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['english_text', 'latin_text'], input_types={}, partial_variables={}, template='Context:\nI due testi che sto per farti analizzare sono uguali. Uno in lingua inglese e uno in lingua latina.\n\nTesto in inglese: {english_text}Testo in latino: {latin_text}Task:\nEsegui named entity recognition ed estrapola anche i luoghi intesi come borghi, navi, carceri, mercati e luoghi similari.\n    Estrapola anche oggetti.\n    Inoltre, crea un breve regesto del documento di massimo 40 parole e individua la data del documento. \n    Trascrivi la data separatamente dal regesto nel seguente formato: anno, mese (a lettere) e giorno, senza interpunzioni tra anno, mese e giorno.\n    Non includere le etichette "Regesto" e "Data del documento", in quanto irrilevanti.\n\n'), additional_kwargs={})]
# content="### Testo in inglese:\n\n**Named Entity Recognition:**\n\n- **Persone:**\n  - Giano Campofregoso\n  - Domenico Colombo\n  - Giovanni (deceased)\n  - Antonino Colombo\n  - Domenichino Colombo\n  - Pasquale Frittalo\n  - Giovanni Frittalo\n  - Battistina\n  - Angelo di Negro\n  - Bartolomeo\n  - Bartolomeo Riccio\n  - Giorgio Clavarino\n  - Giovanni\n  - Matteo Ferrari\n  - Antonio Bassano\n  - Cesare\n  - Taliano Castronovo\n  - Francesco Falcinello\n  - Franceschino Castronovo\n  - Isolino Compiano\n  - Guglielmo Ungaro\n  - Lorenzo\n  - Casamatta\n  - Antonio della Rocchetta\n  - Pietro del Carretto\n  - Bertone di Alpe\n  - Francesco Centa\n  - Arunsino\n  - Guirardo Monsia\n  - Matteo Monsia\n  - Filippo Zucca\n  - Pietro Paolo\n  - Bartolomeo Pevere\n  - Veneziano\n  - Enrico Savignone\n  - Filiberto di Francia\n  - Ser Manfredo\n  - Nardo\n  - Battista Palma\n  - Giovannetto\n  - Bonvexius\n  - Conradus\n  - Georgius\n  - Giovanni\n  - Domenico\n  - Pietro\n  - Bertone\n  - Gerolamo\n  - Luca Compiano\n  - Giovanni\n  - Creseto\n  - Agosto\n  - Antonio Busto\n  - Nicolò\n  - Rinaldo\n  - Giovanni Schiavo\n  - Andrea\n  - Giovanni della Cella\n  - Giorgio Schiavo\n  - Antonio Somma\n  - Giardolo Vacca\n  - Nicolò di Boemia\n  - Antonio Zucca\n  - Ettore Ravaschiero\n  - Antonio Fantone\n  - Giovanni Gatto\n  - Felice Chiavari\n  - Ambrogio Oneto\n  - Giovanni Castiglione\n  - Gerolamo Corso\n  - Antonello\n\n- **Luoghi (borghi, navi, carceri, mercati e simili):**\n  - Genoa\n  - Olivella gate and tower\n  - Quinto\n  - Bisagno\n  - Pietrasanta\n  - Terra\xadrossa\n  - Sarzana\n  - Castronovo\n  - Compiano\n  - Brignano\n  - Trisana\n  - Bargone\n  - Milano\n  - Bavera\n  - Capriata\n  - Firenze\n  - Mestre\n  - Magenta\n  - Sansepolcro\n  - Podenzana\n  - Pontremoli\n  - Eboli\n  - Filattiera\n  - Vallesturla\n  - Forlì\n  - Venezia\n  - Calabria\n  - Boemia\n  - Allemagna\n\n- **Oggetti:**\n  - lire di genovini\n  - silver spoons\n  - horse\n  - notary\n  - servant\n  - adjutant\n\n**Regesto:**\nDomenico Colombo è nominato custode della torre e porta Olivella dal doge Giano Campofregoso. I fratelli Antonino e Domenichino Colombo riconoscono un debito di 60 lire genovini e 6 cucchiai d'argento a Pasquale Frittalo per la dote di Battistina.\n\n**Data del documento:**\n1448 April 20\n\n### Testo in latino:\n\n**Named Entity Recognition:**\n\n- **Persone:**\n  - Dominicus de Columbo\n  - Peregro vitrerio\n  - Antonio de Portu\n  - Benedictus de Solario\n  - Iohannis\n  - Dux\n  - Antoninus\n  - Domenighinus\n  - Pasquali de Fritalo\n  - Iohannis de Fritalo\n  - Iohannis\n  - Angeli de Nigro\n  - Bartholomeo\n  - Bartholomeo Ricio\n  - Georgio Clavarino\n  - Mateus Ferrarius\n  - Antonius Baxanus\n  - Cezarus de Sarzana\n  - Talianus de Castronovo\n  - Franciscus de Facinelo\n  - Franceschinus de Castronovo\n  - Isolinus de Compiano\n  - Gullielmus Ungarus\n  - Laurentius\n  - Antonius de Rocheta\n\n- **Luoghi (borghi, navi, carceri, mercati e simili):**\n  - Aurie\n  - lanuensium\n  - Genoa\n  - Olivele\n  - Quinti\n  - Bisannis\n  - Sarzana\n  - Castronovo\n  - Compiano\n  - Brignano\n  - Trisana\n  - Bargono\n  - Mestr\n  - Mazenta\n  - Sancto Sepulcro\n  - Podensana\n  - Pontremulo\n  - Petrasancta\n  - Rocheta\n\n- **Oggetti:**\n  - libras\n  - possessiones\n  - denarii\n  - coclearia\n  - pannorum\n  - cartulario\n  - dotium\n  - equus\n\n**Regesto:**\nDominicus de Columbo è nominato custode della torre e porta Olivella dal doge Ianus de Campofregoso. Antoninus e Domenighinus fratres de Colombo riconoscono un debito di 60 lire genovini e 6 cucchiai d'argento a Pasquali de Fritalo per la dote di Batestine.\n\n**Data del documento:**\n1448 April 20" additional_kwargs={} response_metadata={'token_usage': {'prompt_tokens': 3535, 'total_tokens': 4973, 'completion_tokens': 1438}, 'model': 'mistral-large-latest', 'finish_reason': 'stop'} id='run-4199af19-9ee9-4180-b9d2-29e411d9cb78-0' usage_metadata={'input_tokens': 35 ...
# Processed: doc\doc11.pdf
# Results saved to: Prompt3-Results-mistral-large-latest-1.0
# Metadata saved to: Prompt3-Results-mistral-large-latest-1.0/JSON
# doc\doc49.pdf
# Prompt3-Results-mistral-large-latest-1.0\doc49.pdf.txt
# Prompt3-Results-mistral-large-latest-1.0/JSON\doc49.pdf.json
# input_variables=['english_text', 'latin_text'] input_types={} partial_variables={} messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Sei un assistente esperto in Named Entity Recognition e analisi testuale, con una profonda conoscenza delle lingue moderna e latina.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['english_text', 'latin_text'], input_types={}, partial_variables={}, template='Context:\nI due testi che sto per farti analizzare sono uguali. Uno in lingua inglese e uno in lingua latina.\n\nTesto in inglese: {english_text}Testo in latino: {latin_text}Task:\nEsegui named entity recognition ed estrapola anche i luoghi intesi come borghi, navi, carceri, mercati e luoghi similari.\n    Estrapola anche oggetti.\n    Inoltre, crea un breve regesto del documento di massimo 40 parole e individua la data del documento. \n    Trascrivi la data separatamente dal regesto nel seguente formato: anno, mese (a lettere) e giorno, senza interpunzioni tra anno, mese e giorno.\n    Non includere le etichette "Regesto" e "Data del documento", in quanto irrilevanti.\n\n'), additional_kwargs={})]
# content="### Analisi del Testo in Inglese\n\n#### Named Entity Recognition (NER)\n\n**Persone:**\n1. Giovanni Colombo\n2. Pasquale Piaggia\n3. Michele Piaggia\n4. Oberto Piaggia\n5. Cristoforo Sisto\n6. Antonio Leverone\n7. Benedetto Colombo\n8. Tommaso Piaggia\n9. Benedetto Dezerga\n10. Pietro Rimassa\n11. Appolonia\n12. Gerolamo delle Vigne\n13. Domenico Colombo\n14. Lanfranco\n15. Bianchinetta\n16. Pellegro Piaggia\n17. Giovanni Rocca\n18. Mariola\n19. Benedictina\n20. Angelini de Columbo\n21. Iohannis de Carrega\n22. Benedictus de Columbo\n23. Pasquali et Michaeli de Plazia\n24. Benedicto de Dezerega\n25. Antonium de Leverono\n26. Oberto de Plazia\n27. Margarita\n28. Iacobus et Baptista de Axereto\n29. Andrea de Petra\n30. Petrus Roymacia\n31. Dominicus de Columbo\n32. Ieronimo de Vineis\n33. Iuliani de Gazio de Usio\n34. Benedicto de Monteburgo\n35. Laurentius de Costa\n36. David de Staliano\n37. Crescio\n38. Moconesi\n39. Battista Tassorello\n40. Pelegro Tassorello\n\n**Luoghi:**\n1. Moconesi\n2. Zoagli\n3. Genoa\n4. Olivella\n5. Portoria\n6. Savona\n7. Cicagna\n8. Moconesi\n9. Porta Sant'Andrea\n\n**Luoghi specifici (borghi, mercati, ecc.):**\n1. Borgo Santo Stefano\n2. Porta Sant'Andrea\n3. Contracta Olivele\n4. Contracta porte Auree\n5. Carrugia\n\n**Oggetti:**\n1. House\n2. Dowry\n3. Cheese\n4. Shop\n\n#### Breve Regesto\n\nGiovanni Colombo riconosce di aver ricevuto 25 lire da Michele Piaggia come parte di un debito di 50 lire. Benedetto Colombo proroga il termine di pagamento di 127 lire ai fratelli Pasquale e Michele Piaggia. Mariola rinuncia ai suoi diritti su una casa in Portoria. Domenico Colombo riconosce un debito di 15 lire a Gerolamo delle Vigne per del formaggio. La data del documento è 1464 febbraio 7." additional_kwargs={} response_metadata={'token_usage': {'prompt_tokens': 8439, 'total_tokens': 9143, 'completion_tokens': 704}, 'model': 'mistral-large-latest', 'finish_reason': 'stop'} id='run-d8abf380-7ab3-4b05-9373-1acace5c8124-0' usage_metadata={'input_tokens': 8439, 'output_tokens': 704, 'total_tokens': 9143}
# Processed: doc\doc49.pdf
# Results saved to: Prompt3-Results-mistral-large-latest-1.0
# Metadata saved to: Prompt3-Results-mistral-large-latest-1.0/JSON
# doc\doc6.pdf
# Prompt3-Results-mistral-large-latest-1.0\doc6.pdf.txt
# Prompt3-Results-mistral-large-latest-1.0/JSON\doc6.pdf.json
# input_variables=['english_text', 'latin_text'] input_types={} partial_variables={} messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Sei un assistente esperto in Named Entity Recognition e analisi testuale, con una profonda conoscenza delle lingue moderna e latina.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['english_text', 'latin_text'], input_types={}, partial_variables={}, template='Context:\nI due testi che sto per farti analizzare sono uguali. Uno in lingua inglese e uno in lingua latina.\n\nTesto in inglese: {english_text}Testo in latino: {latin_text}Task:\nEsegui named entity recognition ed estrapola anche i luoghi intesi come borghi, navi, carceri, mercati e luoghi similari.\n    Estrapola anche oggetti.\n    Inoltre, crea un breve regesto del documento di massimo 40 parole e individua la data del documento. \n    Trascrivi la data separatamente dal regesto nel seguente formato: anno, mese (a lettere) e giorno, senza interpunzioni tra anno, mese e giorno.\n    Non includere le etichette "Regesto" e "Data del documento", in quanto irrilevanti.\n\n'), additional_kwargs={})]
# content='### Named Entity Recognition (NER)\n\n#### Testo in inglese:\n- **Persone:**\n  - Pietro Ghirardetto\n  - Antonio Musante (Fogliazzo)\n  - Lodisio of Pavia\n  - Domenico of Terrarossa\n  - Benedetto of Moconesi\n  - Antonio Bagnara\n  - Stefano Besaccia\n  - Deserino Garro\n  - Antonino (son of Colombo of Moconesi)\n  - Colombo of Moconesi\n\n- **Luoghi (borghi, navi, carceri, mercati e similari):**\n  - Genoa\n  - Borgo Santo Stefano\n  - Quinto\n  - Bisagno\n  - Moconesi\n  - Pavia\n\n- **Oggetti:**\n  - Fifty-two lire and ten soldi di genovini\n  - Plot of land\n  - Chestnut trees\n  - Wooded area\n  - Meadow\n  - Public street\n  - Property\n\n### Testo in latino:\n- **Persone:**\n  - Petrus de Guiratdeto\n  - Antonio de Muzante (Foliacio)\n  - Lodixio de Papia\n  - Dominicus de Terra Rubea\n  - Benedicto de Moconexi\n  - Antonii de Bagneria\n  - Stephani Bezacie\n  - Dexerini Garri\n  - Antonino de Columbo de Moconexi\n  - Columbo de Moconexi\n  - Iohannis\n  - Barthelemy de Faciis\n  - Martini de Faciis\n\n- **Luoghi (borghi, navi, carceri, mercati e similari):**\n  - Ianue (Genoa)\n  - Burgo Sancti Stephani\n  - Quinti\n  - Bisamnis\n  - Moconexi\n  - Papia\n  - Plana Bisamnis\n  - Quarterio Sancti Fructuosi\n\n- **Oggetti:**\n  - Libras quinquaginta duas et soldos decem ianuinorum\n  - Peciam terre\n  - Castaneate et boschive\n  - Prative\n  - Via publica\n  - Terra\n\n### Regesto\nPietro Ghirardetto riconosce pubblicamente di dovere a Antonio Musante cinquantadue lire e dieci soldi genovini. Domenico di Terrarossa vende a Benedetto di Moconesi un terreno a Quinto.\n\n1444 gennaio 21' additional_kwargs={} response_metadata={'token_usage': {'prompt_tokens': 3262, 'total_tokens': 3899, 'completion_tokens': 637}, 'model': 'mistral-large-latest', 'finish_reason': 'stop'} id='run-f640ca7c-c6b0-4392-9afb-564e9496d87e-0' usage_metadata={'input_tokens': 3262, 'output_tokens': 637, 'total_tokens': 3899}
# Processed: doc\doc6.pdf
# Results saved to: Prompt3-Results-mistral-large-latest-1.0
# Metadata saved to: Prompt3-Results-mistral-large-latest-1.0/JSON
# doc\doc75.pdf
# Prompt3-Results-mistral-large-latest-1.0\doc75.pdf.txt
# Prompt3-Results-mistral-large-latest-1.0/JSON\doc75.pdf.json
# input_variables=['english_text', 'latin_text'] input_types={} partial_variables={} messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Sei un assistente esperto in Named Entity Recognition e analisi testuale, con una profonda conoscenza delle lingue moderna e latina.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['english_text', 'latin_text'], input_types={}, partial_variables={}, template='Context:\nI due testi che sto per farti analizzare sono uguali. Uno in lingua inglese e uno in lingua latina.\n\nTesto in inglese: {english_text}Testo in latino: {latin_text}Task:\nEsegui named entity recognition ed estrapola anche i luoghi intesi come borghi, navi, carceri, mercati e luoghi similari.\n    Estrapola anche oggetti.\n    Inoltre, crea un breve regesto del documento di massimo 40 parole e individua la data del documento. \n    Trascrivi la data separatamente dal regesto nel seguente formato: anno, mese (a lettere) e giorno, senza interpunzioni tra anno, mese e giorno.\n    Non includere le etichette "Regesto" e "Data del documento", in quanto irrilevanti.\n\n'), additional_kwargs={})]
# content="### Named Entity Recognition e Estrapolazione degli Oggetti\n\n#### Entità Nominate (Persone, Luoghi, Oggetti)\n\n**Persone:**\n1. Domenico\n2. Christopher (Cristoforo)\n3. Nicola Raggio\n4. Raffaele of Bisagno\n5. Agosto from Pometò\n6. Giovanni Longo del Carmine\n7. Battista Zenoglio\n8. Giovanni Garaventa\n9. Leone Cigala\n10. Guglielmo from Pentema\n11. Angelino Bertegale\n12. Benone Alsarino\n13. Giovanni Boiano\n14. Simone Rossano\n15. Antonio Garibaldo\n16. Cristoforo Rossano\n17. Giovanni from Milano\n18. Giovanni Vencellino\n19. Bertola Chighizola\n20. Nicola Romano\n21. Giacomo from Favale\n22. Simone Correggia\n23. Luca Torriglia\n24. Giovanni Moconesi\n25. Benedetto Viganego\n26. Manuele Romano\n27. Benedetto from Monteborgo\n28. Giovanni from Mondovì\n29. Simone Sperone\n30. Giovanni Pietro Garibaldo\n31. Cristoforo Fregaga\n32. Avanzino Avanzini\n33. Crescio Moconesi\n34. Nicolò Teglia\n35. Agostino Bonaparte\n36. Domenico Garibaldo\n37. Benedetto from Nervi\n38. Benone Zenoglio\n39. Leonardo Graffigna\n40. Gerolamo Crovari\n41. Giov:anni of Vallesturla\n42. Giacomo Capellaccio\n43. Luchino Recroso\n44. Bartolomeo Capellana\n45. Lazzaro from Leivi\n46. Pietro Vignale\n47. Andrea from Pentema\n48. Giovanni Reboiano\n49. Cristoforo of Fontanabuona\n50. Battaglino of Foiyanabuona\n51. Marchino Devoto\n52. Antonio Poserbo\n53. Nicolosino Rissetto\n54. Stefano Rivegno\n55. Giovanni Borzone\n56. Benedetto of Vallesturla\n57. Bartolomeo Rondanina\n58. Benedetto Romano\n59. Giovanni Valasina\n60. Nicolò Vaccarezza\n61. Bertino Lamagna\n62. Bartolomeo Pozzo\n63. Zaccaria from Piacenza\n64. Giovanni Torriglia\n65. Domenichino Castagnino\n66. Simone Trebino\n67. Stefanino from Ortoana\n68. Battista Rebecco\n69. Cogorino Garibaldo\n70. Perrino Mambrilla\n71. Lazarino Rissetto\n72. Battista Senno\n73. Giovanni from Pentema\n74. Giacomo Castruccio\n75. Antonio from Sestri Levante\n76. Cristoforo Bertonasco\n77. Battista de Paolo\n78. Michele Cella\n79. Bartolomeo Taverna\n80. Simone Colonna\n81. Antonio Chichero\n82. Antonio Rapallo\n83. Battista Fontanarossa\n84. Bartolomeo Teglia\n85. Antonio Genoglio\n86. Simone from Trisobbio\n87. Giuliano Molinari\n88. Michele Cigala\n89. Pasqualino from Paggi\n90. Battista Panesi\n91. Giorgio Viganego\n92. Battista from Prato\n93. Simone Carozzo\n94. Giacomo Teutonico\n95. Benedetto from Verzi\n96. Giovanni Costa\n97. Giovanni from Frinti\n98. Antonio di Vigomorasso\n99. Benedetto Rovegno\n100. Antonio Terrile\n101. Nicolò Torriglia\n102. Nicolò Caneva\n103. Domenico Colombo\n104. Antonio Bottino\n105. Pasquale Bogliolo\n106. Pietro Botto\n107. Antonio Brilla\n108. Pellegro Romano\n109. Giovanni Lavello\n110. Pasquale Monleone\n111. Giacomino Garibaldo\n112. Benedetto Celesia\n113. Tommaso Picaiano\n114. Giacomo Desconia\n115. Benedetto Colombo\n116. Battista Razeto\n117. Giovanni Montoggio\n118. Giacomo Castagnelli\n119. Lazzarino di Vallesturla\n120. Giovanni Bertigale\n121. Paolo Moconesi\n122. Giovanni Viganego\n123. Paolo Montedonico\n124. Bartolomeo di Rodi\n125. Giuliano di Vallesturla\n126. Giovanni Molinari\n127. Abramo Moconesi\n128. Benedetto Figone\n129. Pietrino Colla\n130. Leonardus Boiano\n131. Bartolomeo Riceto\n132. Lorenzo from Framura\n133. Christophorus from Pentema\n134. Agostino Decimo\n135. Ottorino Monsia\n136. Antonio Cabona\n137. Giovanni Schinchino\n138. Antonio Varese\n139. Bordino Zenoglio\n140. Abramo Caorsi\n141. Antonio di Apparizione\n142. Giovanni Polcevera\n143. Antonio Recroso\n144. Giovanni Fontanarossa\n145. Quirico Cavassa\n146. Francesco Levaggi\n147. Berto ne Casella\n148. Pasquale Terrile\n149. Giovanni Garibaldo\n150. Matteo Cigala\n151. Domenico Cappelaccio\n152. Manfredo Cigala\n153. Lanfranco Balbo\n154. Guglielmo Conforto\n155. Giacomo Cafferata\n156. Bartolomeo from Tortona\n157. Stefanini from Favale\n158. Valentino Frassineto\n159. Giovanni Romano from Uscio\n160. Nicolò Carrosio\n161. Ambrogio Fontanarossa\n162. Giorgio from Pin ...
# Processed: doc\doc75.pdf
# Results saved to: Prompt3-Results-mistral-large-latest-1.0
# Metadata saved to: Prompt3-Results-mistral-large-latest-1.0/JSON
